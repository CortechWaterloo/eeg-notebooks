# %%
import os
from collections import OrderedDict
import warnings
import h5py
warnings.filterwarnings('ignore')

from mne import Epochs,find_events


from eegnb import generate_save_fn, generate_save_path
from eegnb.devices.eeg import EEG
from eegnb.analysis.utils import load_data,plot_conditions,load_csv_as_raw, makeoddball, maketonesnums, replaceMarkersAndSave
from eegnb.datasets import fetch_dataset
from eegnb.devices.utils import EEG_INDICES, SAMPLE_FREQS

# %%
board_name = 'muse2'
device_name = board_name
experiment = 'auditory_oddball'
subject = 1
session_nb = 1

# %%
# Create save file name
save_fn = generate_save_fn(board_name, experiment, subject, session_nb)
print(save_fn)


eegnb_data_path = generate_save_path(board_name, experiment, subject, session_nb)



raw = load_data(subject, session_nb, device_name, experiment, replace_ch_names=None, verbose=1, site='all', data_dir=None)
# Out:
# C:\Users\surya/.eegnb\data\auditory_oddball\local\muse2\subject0001\session001\recording_2020-12-18-21.18.46.csv
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=281472
#     Range : 0 ... 281471 =      0.000 ...  1099.496 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=281472
#     Range : 0 ... 281471 =      0.000 ...  1099.496 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268656
#     Range : 0 ... 268655 =      0.000 ...  1049.434 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=259812
#     Range : 0 ... 259811 =      0.000 ...  1014.887 secs
# Ready.

# %%
raw.plot_psd()
# Out:
# Effective window size : 8.000 (s)
# Generating pos outlines with sphere [0.    0.    0.    0.095] from [0.    0.    0.    0.095] for eeg
# Generating coords using: [0.    0.    0.    0.095]

# %%
raw.filter(1,30, method='iir')
raw.plot_psd(fmin=1, fmax=30);
# Out:
# Filtering raw data in 8 contiguous segments
# Setting up band-pass filter from 1 - 30 Hz
# Using filter length: 281472
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# Effective window size : 8.000 (s)
# Generating pos outlines with sphere [0.    0.    0.    0.095] from [0.    0.    0.    0.095] for eeg
# Generating coords using: [0.    0.    0.    0.095]

# %%
from mne import merge_events
events = find_events(raw)
# Out:
# 14194 events found
# Event IDs: [    99 111113 111131 111133 111313 111331 111333 113313 113331 113333
#  133313 133322 133332 133333 222222 222233 222422 222423 222433 224422
#  224423 224433 244413 244422 244423 244432 244433 333313 333322 333323
#  333331 333332 333333 444413 444422 444423 444433]

# %%
filename = "sponeoneob3.csv"

tonenums =  maketonesnums(1800)
oddball3 = makeoddball(inputs, 3)
oddball4 = makeoddball(inputs, 4)
oddball5 = makeoddball(inputs, 5)
oddball6 = makeoddball(inputs, 6)
lowPE = np.squeeze(F["museEEG"]["design"]["lowPE"][:]).astype(int)
highPE = np.squeeze(F["museEEG"]["design"]["highPE"][:]).astype(int)

for i in range(len(highPE)):
    if highPE[i] == 0:
        highPE[i] = 3
    if lowPE[i] == 0:
        lowPE[i] = 3

newMarkers = 

events = replaceMarkers(events, newMarkers)
# Out:
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=281472
#     Range : 0 ... 281471 =      0.000 ...  1099.496 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=281472
#     Range : 0 ... 281471 =      0.000 ...  1099.496 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268656
#     Range : 0 ... 268655 =      0.000 ...  1049.434 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=259812
#     Range : 0 ... 259811 =      0.000 ...  1014.887 secs
# Ready.
# 14194 events found
# Event IDs: [    99 111113 111131 111133 111313 111331 111333 113313 113331 113333
#  133313 133322 133332 133333 222222 222233 222422 222423 222433 224422
#  224423 224433 244413 244422 244423 244432 244433 333313 333322 333323
#  333331 333332 333333 444413 444422 444423 444433]

# %%
#run only if a new compilation file needs to be saved
replaceMarkersAndSave(board_name, experiment, subject, session_nb, newMarkers, filename)
# Out:
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=281472
#     Range : 0 ... 281471 =      0.000 ...  1099.496 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=281472
#     Range : 0 ... 281471 =      0.000 ...  1099.496 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268656
#     Range : 0 ... 268655 =      0.000 ...  1049.434 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=268668
#     Range : 0 ... 268667 =      0.000 ...  1049.480 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=259812
#     Range : 0 ... 259811 =      0.000 ...  1014.887 secs
# Ready.
# ['TP9', 'AF7', 'AF8', 'TP10', 'Right AUX', 'stim']
# Creating RawArray with float64 data, n_channels=6, n_times=2166084
#     Range : 0 ... 2166083 =      0.000 ...  8461.262 secs
# Ready.
# 28388 events found
# Event IDs: [    99  90000  90001 ... 444422 444423 444433]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b427bd785c0c> in <module>
# ----> 1 replaceMarkersAndSave(board_name, experiment, subject, session_nb, newMarkers, filename)
#
# ~\Documents\eegnote\mastermmn\eeg-notebooks\eegnb\analysis\utils.py in replaceMarkersAndSave(board_name, experiment, subject, session_nb, newMarkers, filename)
#     340     raw.add_events(events = newEvents, stim_channel = "stim", replace = True)
#     341     rawDF = raw.to_data_frame(picks = "all", copy = True)
# --> 342     rawDF.to_csv(eegnb_data_path + "/" + filename, index = False)
#     343
#     344 def makeoddball(inputs, rep):
#
# c:\users\surya\anaconda3\envs\ntxenv\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3165             decimal=decimal,
#    3166         )
# -> 3167         formatter.save()
#    3168
#    3169         if path_or_buf is None:
#
# c:\users\surya\anaconda3\envs\ntxenv\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     204             )
#     205
# --> 206             self._save()
#     207
#     208         finally:
#
# c:\users\surya\anaconda3\envs\ntxenv\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     326                 break
#     327
# --> 328             self._save_chunk(start_i, end_i)
#     329
#     330     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# c:\users\surya\anaconda3\envs\ntxenv\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     360         )
#     361
# --> 362         libwriters.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#
# pandas\_libs\writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
#for classic oddball definitions

event_id = {'Standard': 1, 'Deviant': 2, 'Non-Standard Repeat': 3, 'Early Deviant': 4}

epochs = Epochs(raw, events=events, event_id=event_id,
                tmin=-0.1, tmax=0.8, baseline=None,
                reject={'eeg': 75e-6}, preload=True,
                verbose=False, picks=[0,1,2,3])


conditions = OrderedDict()
conditions['Standard'] = [1]
conditions['Deviant'] = [2]
#conditions['Neither'] = [333333]

fig, ax = plot_conditions(epochs, conditions=conditions,
                          ci=97.5, n_boot=1000, title='Classic Oddball',
                          diff_waveform=(1, 2))

print('sample drop %: ', (1 - len(epochs.events)/len(cevents)) * 100)
epochs

# %%
#for PE based definitions

event_id = {'Bottom 15 Percentile': 1, 'Top 15 Percentile': 2, 'Neither': 3}

epochs = Epochs(raw, events=events, event_id=event_id,
                tmin=-0.1, tmax=0.8, baseline=None,
                reject={'eeg': 75e-6}, preload=True,
                verbose=False, picks=[0,1,2,3])


conditions = OrderedDict()
conditions['Bottom 15 Percentile'] = [1]
conditions['Top 15 Percentile'] = [2]
#conditions['Neither'] = [333333]

fig, ax = plot_conditions(epochs, conditions=conditions,
                          ci=97.5, n_boot=1000, title='Prediction Error Based',
                          diff_waveform=(1, 2))

print('sample drop %: ', (1 - len(epochs.events)/len(cevents)) * 100)
epochs

# %%
epochs = Epochs(raw, events=cevents, event_id=event_id,
                tmin=-0.1, tmax=0.8, baseline=None,
                reject={'eeg': 75e-6}, preload=True,
                verbose=False, picks=[0,1,2,3])
